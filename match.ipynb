# %%
import numpy as np
import pandas as pd
df=pd.read_csv("C:/Users/meher/Downloads/match.csv")
df
# Out:
#       Unnamed: 0  match_number                                 name  \
# 0           1417           1.0                   Bangladesh v India
# 1           1418           1.0                   Bangladesh v India
# 2           1419           2.0                   Bangladesh v India
# 3           1420           2.0                   Bangladesh v India
# 4           1421           3.0                   Bangladesh v India
# ...          ...           ...                                  ...
# 6194        6198           3.0                      India v England
# 6195        6062           7.0       Sydney Thunder v Brisbane Heat
# 6196        6061           7.0       Sydney Thunder v Brisbane Heat
# 6197        6131          36.0  Adelaide Strikers v Melbourne Stars
# 6198        6132          36.0  Adelaide Strikers v Melbourne Stars
#
#                      start_date matchtype  series_id  match_detail_id  \
# 0     2004-12-22 18:30:00+00:00       odi        182              773
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# match_number       75
# name                2
# start_date          0
# matchtype           4
# series_id           0
# match_detail_id     0
# scorecard_id        0
# title               0
# runs                0
# over                0
# run_rate            0
# match_id            0
# opp_team_id         0
# team_id             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6199 entries, 0 to 6198
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       6199 non-null   int64
#  1   match_number     6124 non-null   float64
#  2   name             6197 non-null   object
#  3   start_date       6199 non-null   object
#  4   matchtype        6195 non-null   object
#  5   series_id        6199 non-null   int64
#  6   match_detail_id  6199 non-null   int64
#  7   scorecard_id     6199 non-null   int64
#  8   title            6199 non-null   object
#  9   runs             6199 non-null   int64
#  10  over             6199 non-null   float64
#  11  run_rate         6199 non-null   float64
#  12  match_id         6199 non-null   int64
#  13  opp_team_id      6199 non-null   int64
#  14  team_id          6199 non-null   int64
# dtypes: float64(3), int64(8), object(4)
# memory usage: 726.6+ KB

# %%
df['matchtype'].fillna(method='ffill',inplace=True)
print(df)
# Out:
#       Unnamed: 0  match_number                                 name  \
# 0           1417           1.0                   Bangladesh v India
# 1           1418           1.0                   Bangladesh v India
# 2           1419           2.0                   Bangladesh v India
# 3           1420           2.0                   Bangladesh v India
# 4           1421           3.0                   Bangladesh v India
# ...          ...           ...                                  ...
# 6194        6198           3.0                      India v England
# 6195        6062           7.0       Sydney Thunder v Brisbane Heat
# 6196        6061           7.0       Sydney Thunder v Brisbane Heat
# 6197        6131          36.0  Adelaide Strikers v Melbourne Stars
# 6198        6132          36.0  Adelaide Strikers v Melbourne Stars
#
#                      start_date matchtype  series_id  match_detail_id  \
# 0     2004-12-22 18:30:00+00:00       odi        182              773
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6199 entries, 0 to 6198
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       6199 non-null   int64
#  1   match_number     6124 non-null   float64
#  2   name             6197 non-null   object
#  3   start_date       6199 non-null   object
#  4   matchtype        6199 non-null   object
#  5   series_id        6199 non-null   int64
#  6   match_detail_id  6199 non-null   int64
#  7   scorecard_id     6199 non-null   int64
#  8   title            6199 non-null   object
#  9   runs             6199 non-null   int64
#  10  over             6199 non-null   float64
#  11  run_rate         6199 non-null   float64
#  12  match_id         6199 non-null   int64
#  13  opp_team_id      6199 non-null   int64
#  14  team_id          6199 non-null   int64
# dtypes: float64(3), int64(8), object(4)
# memory usage: 726.6+ KB

# %%
df['match_number'].fillna(method='ffill',inplace=True)
print(df)
# Out:
#       Unnamed: 0  match_number  name  start_date  matchtype  series_id  \
# 0           1417           1.0   NaN         NaN          0        182
# 1           1418           1.0   NaN         NaN          0        182
# 2           1419           2.0   NaN         NaN          0        182
# 3           1420           2.0   NaN         NaN          0        182
# 4           1421           3.0   NaN         NaN          0        182
# ...          ...           ...   ...         ...        ...        ...
# 6194        6198           3.0   NaN         NaN          2         27
# 6195        6062           7.0   NaN         NaN          1        505
# 6196        6061           7.0   NaN         NaN          1        505
# 6197        6131          36.0   NaN         NaN          1        505
# 6198        6132          36.0   NaN         NaN          1        505
#
#       match_detail_id  scorecard_id  title  runs  over  run_rate  match_id  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# match_number       0
# name               2
# start_date         0
# matchtype          0
# series_id          0
# match_detail_id    0
# scorecard_id       0
# title              0
# runs               0
# over               0
# run_rate           0
# match_id           0
# opp_team_id        0
# team_id            0
# dtype: int64

# %%
df['name'].fillna(method='ffill',inplace=True)
print(df)
# Out:
#       Unnamed: 0  match_number                                 name  \
# 0           1417           1.0                   Bangladesh v India
# 1           1418           1.0                   Bangladesh v India
# 2           1419           2.0                   Bangladesh v India
# 3           1420           2.0                   Bangladesh v India
# 4           1421           3.0                   Bangladesh v India
# ...          ...           ...                                  ...
# 6194        6198           3.0                      India v England
# 6195        6062           7.0       Sydney Thunder v Brisbane Heat
# 6196        6061           7.0       Sydney Thunder v Brisbane Heat
# 6197        6131          36.0  Adelaide Strikers v Melbourne Stars
# 6198        6132          36.0  Adelaide Strikers v Melbourne Stars
#
#                      start_date matchtype  series_id  match_detail_id  \
# 0     2004-12-22 18:30:00+00:00       odi        182              773
# ...

# %% [markdown]
# df.isnull().sum()

# %%
pd.get_dummies(df,columns=['matchtype','name'])
# Out:
#       Unnamed: 0  match_number                 start_date  series_id  \
# 0           1417           1.0  2004-12-22 18:30:00+00:00        182
# 1           1418           1.0  2004-12-22 18:30:00+00:00        182
# 2           1419           2.0  2004-12-25 18:30:00+00:00        182
# 3           1420           2.0  2004-12-25 18:30:00+00:00        182
# 4           1421           3.0  2004-12-26 18:30:00+00:00        182
# ...          ...           ...                        ...        ...
# 6194        6198           3.0  2021-02-24 14:30:00+00:00         27
# 6195        6062           7.0  2021-03-10 09:54:41+00:00        505
# 6196        6061           7.0  2021-03-10 09:54:41+00:00        505
# 6197        6131          36.0  2021-03-10 09:54:55+00:00        505
# 6198        6132          36.0  2021-03-10 09:54:55+00:00        505
#
#       match_detail_id  scorecard_id                      title  runs  over  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6199 entries, 0 to 6198
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       6199 non-null   int64
#  1   match_number     6199 non-null   float64
#  2   name             6199 non-null   object
#  3   start_date       6199 non-null   object
#  4   matchtype        6199 non-null   object
#  5   series_id        6199 non-null   int64
#  6   match_detail_id  6199 non-null   int64
#  7   scorecard_id     6199 non-null   int64
#  8   title            6199 non-null   object
#  9   runs             6199 non-null   int64
#  10  over             6199 non-null   float64
#  11  run_rate         6199 non-null   float64
#  12  match_id         6199 non-null   int64
#  13  opp_team_id      6199 non-null   int64
#  14  team_id          6199 non-null   int64
# dtypes: float64(3), int64(8), object(4)
# memory usage: 726.6+ KB

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df['matchtype']=label_encoder.fit_transform(df['matchtype'])
df=df.apply(pd.to_numeric,errors='coerce')
df
# Out:
#       Unnamed: 0  match_number  name  start_date  matchtype  series_id  \
# 0           1417           1.0   NaN         NaN          0        182
# 1           1418           1.0   NaN         NaN          0        182
# 2           1419           2.0   NaN         NaN          0        182
# 3           1420           2.0   NaN         NaN          0        182
# 4           1421           3.0   NaN         NaN          0        182
# ...          ...           ...   ...         ...        ...        ...
# 6194        6198           3.0   NaN         NaN          2         27
# 6195        6062           7.0   NaN         NaN          1        505
# 6196        6061           7.0   NaN         NaN          1        505
# 6197        6131          36.0   NaN         NaN          1        505
# 6198        6132          36.0   NaN         NaN          1        505
#
#       match_detail_id  scorecard_id  title  runs  over  run_rate  match_id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6199 entries, 0 to 6198
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       6199 non-null   int64
#  1   match_number     6199 non-null   float64
#  2   name             0 non-null      float64
#  3   start_date       0 non-null      float64
#  4   matchtype        6199 non-null   int32
#  5   series_id        6199 non-null   int64
#  6   match_detail_id  6199 non-null   int64
#  7   scorecard_id     6199 non-null   int64
#  8   title            0 non-null      float64
#  9   runs             6199 non-null   int64
#  10  over             6199 non-null   float64
#  11  run_rate         6199 non-null   float64
#  12  match_id         6199 non-null   int64
#  13  opp_team_id      6199 non-null   int64
#  14  team_id          6199 non-null   int64
# dtypes: float64(6), int32(1), int64(8)
# memory usage: 702.4 KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# match_number          0
# name               6199
# start_date         6199
# matchtype             0
# series_id             0
# match_detail_id       0
# scorecard_id          0
# title              6199
# runs                  0
# over                  0
# run_rate              0
# match_id              0
# opp_team_id           0
# team_id               0
# dtype: int64

# %%
df['name'].fillna(method='ffill',inplace=True)
print(df)
# Out:
#       Unnamed: 0  match_number  name  start_date  matchtype  series_id  \
# 0           1417           1.0   NaN         NaN          0        182
# 1           1418           1.0   NaN         NaN          0        182
# 2           1419           2.0   NaN         NaN          0        182
# 3           1420           2.0   NaN         NaN          0        182
# 4           1421           3.0   NaN         NaN          0        182
# ...          ...           ...   ...         ...        ...        ...
# 6194        6198           3.0   NaN         NaN          2         27
# 6195        6062           7.0   NaN         NaN          1        505
# 6196        6061           7.0   NaN         NaN          1        505
# 6197        6131          36.0   NaN         NaN          1        505
# 6198        6132          36.0   NaN         NaN          1        505
#
#       match_detail_id  scorecard_id  title  runs  over  run_rate  match_id  \
# ...

# %%
df['title'].fillna(method='ffill',inplace=True)
print(df)
# Out:
#       Unnamed: 0  match_number  name  start_date  matchtype  series_id  \
# 0           1417           1.0   NaN         NaN          0        182
# 1           1418           1.0   NaN         NaN          0        182
# 2           1419           2.0   NaN         NaN          0        182
# 3           1420           2.0   NaN         NaN          0        182
# 4           1421           3.0   NaN         NaN          0        182
# ...          ...           ...   ...         ...        ...        ...
# 6194        6198           3.0   NaN         NaN          2         27
# 6195        6062           7.0   NaN         NaN          1        505
# 6196        6061           7.0   NaN         NaN          1        505
# 6197        6131          36.0   NaN         NaN          1        505
# 6198        6132          36.0   NaN         NaN          1        505
#
#       match_detail_id  scorecard_id  title  runs  over  run_rate  match_id  \
# ...

# %%
df['start_date'].fillna(method='ffill',inplace=True)
print(df)
# Out:
#       Unnamed: 0  match_number  name  start_date  matchtype  series_id  \
# 0           1417           1.0   NaN         NaN          0        182
# 1           1418           1.0   NaN         NaN          0        182
# 2           1419           2.0   NaN         NaN          0        182
# 3           1420           2.0   NaN         NaN          0        182
# 4           1421           3.0   NaN         NaN          0        182
# ...          ...           ...   ...         ...        ...        ...
# 6194        6198           3.0   NaN         NaN          2         27
# 6195        6062           7.0   NaN         NaN          1        505
# 6196        6061           7.0   NaN         NaN          1        505
# 6197        6131          36.0   NaN         NaN          1        505
# 6198        6132          36.0   NaN         NaN          1        505
#
#       match_detail_id  scorecard_id  title  runs  over  run_rate  match_id  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# match_number          0
# name               6199
# start_date         6199
# matchtype             0
# series_id             0
# match_detail_id       0
# scorecard_id          0
# title              6199
# runs                  0
# over                  0
# run_rate              0
# match_id              0
# opp_team_id           0
# team_id               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6199 entries, 0 to 6198
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       6199 non-null   int64
#  1   match_number     6124 non-null   float64
#  2   name             6197 non-null   object
#  3   start_date       6199 non-null   object
#  4   matchtype        6195 non-null   object
#  5   series_id        6199 non-null   int64
#  6   match_detail_id  6199 non-null   int64
#  7   scorecard_id     6199 non-null   int64
#  8   title            6199 non-null   object
#  9   runs             6199 non-null   int64
#  10  over             6199 non-null   float64
#  11  run_rate         6199 non-null   float64
#  12  match_id         6199 non-null   int64
#  13  opp_team_id      6199 non-null   int64
#  14  team_id          6199 non-null   int64
# dtypes: float64(3), int64(8), object(4)
# memory usage: 726.6+ KB

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df['matchtype']=label_encoder.fit_transform(df['matchtype'])
df=df.apply(pd.to_numeric,errors='coerce')
df
# Out:
#       Unnamed: 0  match_number  name  start_date  matchtype  series_id  \
# 0           1417           1.0   NaN         NaN          0        182
# 1           1418           1.0   NaN         NaN          0        182
# 2           1419           2.0   NaN         NaN          0        182
# 3           1420           2.0   NaN         NaN          0        182
# 4           1421           3.0   NaN         NaN          0        182
# ...          ...           ...   ...         ...        ...        ...
# 6194        6198           3.0   NaN         NaN          2         27
# 6195        6062           7.0   NaN         NaN          1        505
# 6196        6061           7.0   NaN         NaN          1        505
# 6197        6131          36.0   NaN         NaN          1        505
# 6198        6132          36.0   NaN         NaN          1        505
#
#       match_detail_id  scorecard_id  title  runs  over  run_rate  match_id  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# match_number         75
# name               6199
# start_date         6199
# matchtype             0
# series_id             0
# match_detail_id       0
# scorecard_id          0
# title              6199
# runs                  0
# over                  0
# run_rate              0
# match_id              0
# opp_team_id           0
# team_id               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df['title']=label_encoder.fit_transform(df['matchtype'])
df=df.apply(pd.to_numeric,errors='coerce')
df
# Out:
#       Unnamed: 0  match_number  name  start_date  matchtype  series_id  \
# 0           1417           1.0   NaN         NaN          0        182
# 1           1418           1.0   NaN         NaN          0        182
# 2           1419           2.0   NaN         NaN          0        182
# 3           1420           2.0   NaN         NaN          0        182
# 4           1421           3.0   NaN         NaN          0        182
# ...          ...           ...   ...         ...        ...        ...
# 6194        6198           3.0   NaN         NaN          2         27
# 6195        6062           7.0   NaN         NaN          1        505
# 6196        6061           7.0   NaN         NaN          1        505
# 6197        6131          36.0   NaN         NaN          1        505
# 6198        6132          36.0   NaN         NaN          1        505
#
#       match_detail_id  scorecard_id  title  runs  over  run_rate  match_id  \
# ...

# %%
df.isnull()
# Out:
#       Unnamed: 0  match_number  name  start_date  matchtype  series_id  \
# 0          False         False  True        True      False      False
# 1          False         False  True        True      False      False
# 2          False         False  True        True      False      False
# 3          False         False  True        True      False      False
# 4          False         False  True        True      False      False
# ...          ...           ...   ...         ...        ...        ...
# 6194       False         False  True        True      False      False
# 6195       False         False  True        True      False      False
# 6196       False         False  True        True      False      False
# 6197       False         False  True        True      False      False
# 6198       False         False  True        True      False      False
#
#       match_detail_id  scorecard_id  title   runs   over  run_rate  match_id  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# match_number         75
# name               6199
# start_date         6199
# matchtype             0
# series_id             0
# match_detail_id       0
# scorecard_id          0
# title                 0
# runs                  0
# over                  0
# run_rate              0
# match_id              0
# opp_team_id           0
# team_id               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df['name']=label_encoder.fit_transform(df['matchtype'])
df=df.apply(pd.to_numeric,errors='coerce')
df
# Out:
#       Unnamed: 0  match_number  name  start_date  matchtype  series_id  \
# 0           1417           1.0     0         NaN          0        182
# 1           1418           1.0     0         NaN          0        182
# 2           1419           2.0     0         NaN          0        182
# 3           1420           2.0     0         NaN          0        182
# 4           1421           3.0     0         NaN          0        182
# ...          ...           ...   ...         ...        ...        ...
# 6194        6198           3.0     2         NaN          2         27
# 6195        6062           7.0     1         NaN          1        505
# 6196        6061           7.0     1         NaN          1        505
# 6197        6131          36.0     1         NaN          1        505
# 6198        6132          36.0     1         NaN          1        505
#
#       match_detail_id  scorecard_id  title  runs  over  run_rate  match_id  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# match_number         75
# name                  0
# start_date         6199
# matchtype             0
# series_id             0
# match_detail_id       0
# scorecard_id          0
# title                 0
# runs                  0
# over                  0
# run_rate              0
# match_id              0
# opp_team_id           0
# team_id               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df['start_date']=label_encoder.fit_transform(df['matchtype'])
df=df.apply(pd.to_numeric,errors='coerce')
df
# Out:
#       Unnamed: 0  match_number  name  start_date  matchtype  series_id  \
# 0           1417           1.0     0           0          0        182
# 1           1418           1.0     0           0          0        182
# 2           1419           2.0     0           0          0        182
# 3           1420           2.0     0           0          0        182
# 4           1421           3.0     0           0          0        182
# ...          ...           ...   ...         ...        ...        ...
# 6194        6198           3.0     2           2          2         27
# 6195        6062           7.0     1           1          1        505
# 6196        6061           7.0     1           1          1        505
# 6197        6131          36.0     1           1          1        505
# 6198        6132          36.0     1           1          1        505
#
#       match_detail_id  scorecard_id  title  runs  over  run_rate  match_id  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# match_number       75
# name                0
# start_date          0
# matchtype           0
# series_id           0
# match_detail_id     0
# scorecard_id        0
# title               0
# runs                0
# over                0
# run_rate            0
# match_id            0
# opp_team_id         0
# team_id             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6199 entries, 0 to 6198
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       6199 non-null   int64
#  1   match_number     6124 non-null   float64
#  2   name             6199 non-null   int64
#  3   start_date       6199 non-null   int64
#  4   matchtype        6199 non-null   int32
#  5   series_id        6199 non-null   int64
#  6   match_detail_id  6199 non-null   int64
#  7   scorecard_id     6199 non-null   int64
#  8   title            6199 non-null   int64
#  9   runs             6199 non-null   int64
#  10  over             6199 non-null   float64
#  11  run_rate         6199 non-null   float64
#  12  match_id         6199 non-null   int64
#  13  opp_team_id      6199 non-null   int64
#  14  team_id          6199 non-null   int64
# dtypes: float64(3), int32(1), int64(11)
# memory usage: 702.4 KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# match_number       75
# name                0
# start_date          0
# matchtype           0
# series_id           0
# match_detail_id     0
# scorecard_id        0
# title               0
# runs                0
# over                0
# run_rate            0
# match_id            0
# opp_team_id         0
# team_id             0
# dtype: int64

# %%
df['match_number'].mean()
# Out:
# 11.217015022860876

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6199 entries, 0 to 6198
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       6199 non-null   int64
#  1   match_number     6124 non-null   float64
#  2   name             6199 non-null   int64
#  3   start_date       6199 non-null   int64
#  4   matchtype        6199 non-null   int32
#  5   series_id        6199 non-null   int64
#  6   match_detail_id  6199 non-null   int64
#  7   scorecard_id     6199 non-null   int64
#  8   title            6199 non-null   int64
#  9   runs             6199 non-null   int64
#  10  over             6199 non-null   float64
#  11  run_rate         6199 non-null   float64
#  12  match_id         6199 non-null   int64
#  13  opp_team_id      6199 non-null   int64
#  14  team_id          6199 non-null   int64
# dtypes: float64(3), int32(1), int64(11)
# memory usage: 702.4 KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# match_number       75
# name                0
# start_date          0
# matchtype           0
# series_id           0
# match_detail_id     0
# scorecard_id        0
# title               0
# runs                0
# over                0
# run_rate            0
# match_id            0
# opp_team_id         0
# team_id             0
# dtype: int64

# %%
df['match_number'].fillna(method='ffill',inplace=True)
print(df)
# Out:
#       Unnamed: 0  match_number  name  start_date  matchtype  series_id  \
# 0           1417           1.0     0           0          0        182
# 1           1418           1.0     0           0          0        182
# 2           1419           2.0     0           0          0        182
# 3           1420           2.0     0           0          0        182
# 4           1421           3.0     0           0          0        182
# ...          ...           ...   ...         ...        ...        ...
# 6194        6198           3.0     2           2          2         27
# 6195        6062           7.0     1           1          1        505
# 6196        6061           7.0     1           1          1        505
# 6197        6131          36.0     1           1          1        505
# 6198        6132          36.0     1           1          1        505
#
#       match_detail_id  scorecard_id  title  runs  over  run_rate  match_id  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# match_number       0
# name               0
# start_date         0
# matchtype          0
# series_id          0
# match_detail_id    0
# scorecard_id       0
# title              0
# runs               0
# over               0
# run_rate           0
# match_id           0
# opp_team_id        0
# team_id            0
# dtype: int64

# %%
X = df.iloc[:, 0:4].values
y = df.iloc[:, 4].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 25)

# %%
print("Shape of X_train: ",X_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_train: ",y_train.shape)
print("Shape of y_test",y_test.shape)
# Out:
# Shape of X_train:  (4339, 4)
# Shape of X_test:  (1860, 4)
# Shape of y_train:  (4339, 1)
# Shape of y_test (1860, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor_linear = LinearRegression()
regressor_linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import seaborn as sns
corr = df.corr()
#Plot figsize
fig, ax = plt.subplots(figsize=(10, 10))
#Generate Heat Map, allow annotations and place floats in map
sns.heatmap(corr, cmap='RdBu', annot=True, fmt=".2f")
#Apply xticks
plt.xticks(range(len(corr.columns)), corr.columns);
#Apply yticks
plt.yticks(range(len(corr.columns)), corr.columns)
#show plot
plt.show()
